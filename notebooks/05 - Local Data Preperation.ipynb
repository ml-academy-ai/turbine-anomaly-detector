# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('../data/01_raw/df_train_test.parquet')

# %%
df = df[df['Power'] > 20]

# %%
df.shape

# %%
df_train = df[:30_000]

# %%
df_test = df[30_000:]

# %%
df_train.shape

# %%
df_test.shape

# %%
df_train.to_parquet('../data/01_raw/df_train.parquet')
df_test.to_parquet('../data/01_raw/df_inference.parquet')
